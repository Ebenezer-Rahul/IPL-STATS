# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
import random
from IPython.display import display

# %%
ipl_deliveries = './IPL Ball-by-Ball 2008-2020.csv'
ipl_match = './archive/IPL Matches 2008-2020.csv'

# %%
ipl_deliveries = pd.read_csv(ipl_deliveries)
ipl_matches = pd.read_csv(ipl_match)

# %%
ipl_matches
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
matches = {}

# %%
    #if(matches.get(delivery['id']) == None):
        #mathches[delivery['id']] = (delivery['batting_team'], delivery['bowling_team'])

# %%
combine_data = pd.merge(ipl_deliveries,ipl_matches,on='id')

# %%
pd.set_option('display.max_columns', 70000)

# %%
regex_patern = r'(2016-*)'

# %%
combine_data.loc[lambda x: x['date'].str.contains(regex_patern, regex = True)]
# Out:
# /tmp/ipykernel_16973/2677790530.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   combine_data.loc[lambda x: x['date'].str.contains(regex_patern, regex = True)]
#             id  inning  over  ball         batsman     non_striker  \
# 122434  980901       1     1     1       RG Sharma     LMP Simmons
# 122435  980901       1     0     4       RG Sharma     LMP Simmons
# 122436  980901       1     0     5       RG Sharma     LMP Simmons
# 122437  980901       1     0     6     LMP Simmons       RG Sharma
# 122438  980901       1     1     5       HH Pandya     LMP Simmons
# ...        ...     ...   ...   ...             ...             ...
# 136525  981019       2     6     4         V Kohli        CH Gayle
# 136526  981019       2    12     2         V Kohli  AB de Villiers
# 136527  981019       2    12     3         V Kohli  AB de Villiers
# ...

# %%
ipl_matches.loc[lambda x: x['date'].str.contains(regex_patern, regex = True)]
# Out:
# /tmp/ipykernel_16973/3765791548.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   ipl_matches.loc[lambda x: x['date'].str.contains(regex_patern, regex = True)]
#          id           city        date    player_of_match  \
# 517  980901         Mumbai  2016-04-09          AM Rahane
# 518  980903        Kolkata  2016-04-10         AD Russell
# 519  980905     Chandigarh  2016-04-11           AJ Finch
# 520  980907      Bangalore  2016-04-12     AB de Villiers
# 521  980909        Kolkata  2016-04-13          RG Sharma
# 522  980911         Rajkot  2016-04-14           AJ Finch
# 523  980913          Delhi  2016-04-15           A Mishra
# 524  980915      Hyderabad  2016-04-16          G Gambhir
# 525  980917         Mumbai  2016-04-16           AJ Finch
# 526  980919     Chandigarh  2016-04-17            M Vohra
# 527  980921      Bangalore  2016-04-17          Q de Kock
# ...

# %%
class Team :
    def __init__(self, team_id, points, team_name, num_of_matches, num_Won, num_Lost):
        self.team_id = team_id
        self.points = points
        self.team_name = team_name
        self.num_of_matches = num_of_matches
        self.num_Won = num_Won
        self.num_Lost = num_Lost
        pass

# %%
class Match:
    def __init__(self, match_id, toss_winner_id, toss_decision, date, city, venue, team1, team2, winner, result, result_margin, umpire1,umpire2, team1_runs, team2_runs, team1_wickets, team2_wickets, man_of_match):
        self.match_id = match_id
        self.toss_winner_id = toss_winner_id
        self.toss_decision = toss_decision
        self.date = date
        self.city = city
        self.venue = venue
        self.team1 = team1
        self.team2 = team2
        self.winner = winner
        self.result = result
        self.result_margin = result_margin
        self.umpire1 = umpire1
        self.umpire2 = umpire2
        self.team1_runs = team1_runs
        self.team2_runs = team2_runs
        self.team1_wickets = team1_wickets
        self.team2_wickets = team2_wickets
        self.man_of_Match = man_of_match
        pass

# %%
class Player:
    def __init__(self, player_id, team_id, player_name):
        self.player_id = player_id
        self.team_id = team_id
        self.player_name = player_name
        self.runs = 0
        self.wickets = 0
        self.best_score = 0
        self.dismissals = 0
        self.innings_played = 0
        self.number_of_balls_faced = 0
        self.number_of_sixes = 0
        self.number_of_fours = 0
        self.num_of_balls_bowled = 0
        self.number_of_boundries = 0
        self.run_outs = 0
        self.run_outs_taken = 0
        self.num_catches = 0
        self.strike_rate = 0.0
        self.num_runs_given = 0
        pass

# %%
data_2016 = combine_data.loc[lambda x: x['date'].str.contains(regex_patern, regex = True)]
# Out:
# /tmp/ipykernel_16973/3978725662.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   data_2016 = combine_data.loc[lambda x: x['date'].str.contains(regex_patern, regex = True)]

# %%
data_2016
# Out:
#             id  inning  over  ball         batsman     non_striker  \
# 122434  980901       1     1     1       RG Sharma     LMP Simmons
# 122435  980901       1     0     4       RG Sharma     LMP Simmons
# 122436  980901       1     0     5       RG Sharma     LMP Simmons
# 122437  980901       1     0     6     LMP Simmons       RG Sharma
# 122438  980901       1     1     5       HH Pandya     LMP Simmons
# ...        ...     ...   ...   ...             ...             ...
# 136525  981019       2     6     4         V Kohli        CH Gayle
# 136526  981019       2    12     2         V Kohli  AB de Villiers
# 136527  981019       2    12     3         V Kohli  AB de Villiers
# 136528  981019       2    11     6  AB de Villiers         V Kohli
# 136529  981019       2    12     1  AB de Villiers         V Kohli
#
#               bowler  batsman_runs  extra_runs  total_runs  non_boundary  \
# 122434      I Sharma             0           0           0             0
# ...

# %%
count = 0
player_exists = {}
players = {}
team_exists = {'nan':'nan'}
teams = {}
match_exists = {}
matches = {}

# %%
team_id = 1
player_id = 1
for index,data in data_2016.iterrows():
    if(team_exists.get(data['team1']) == None):
        new_team = Team(team_id,0, data['team1'], 0,0,0)
        team_exists[data['team1']] = team_id
        teams[team_id] = new_team
        team_id += 1
        print(new_team.team_name)
        count += 1
        
for index,data in data_2016.iterrows():
    if(player_exists.get(data['batsman']) == None):
        new_player = Player(player_id, team_exists[data['batting_team']], data['batsman'])
        player_exists[data['batsman']] = player_id
        players[player_id] = new_player
        player_id += 1
        
        
    if(player_exists.get(data['non_striker']) == None):
        new_player = Player(player_id, team_exists[data['batting_team']], data['non_striker'])
        player_exists[data['non_striker']] = player_id
        players[player_id] = new_player
        player_id += 1
        
    if(player_exists.get(data['bowler']) == None):
        new_player = Player(player_id, team_exists[data['bowling_team']], data['bowler'])
        player_exists[data['bowler']] = player_id
        players[player_id] = new_player
        player_id += 1
    

print(count)
# Out:
# Mumbai Indians
# Kolkata Knight Riders
# Kings XI Punjab
# Royal Challengers Bangalore
# Gujarat Lions
# Delhi Daredevils
# Sunrisers Hyderabad
# Rising Pune Supergiants
# 8

# %%
num_pl = 0
for key in players.keys():
    print(f'{players[key].player_name}, {teams[players[key].team_id].team_name}')
    num_pl += 1
print(num_pl)
# Out:
# RG Sharma, Mumbai Indians
# LMP Simmons, Mumbai Indians
# I Sharma, Rising Pune Supergiants
# RP Singh, Rising Pune Supergiants
# HH Pandya, Mumbai Indians
# AT Rayudu, Mumbai Indians
# JC Buttler, Mumbai Indians
# MR Marsh, Rising Pune Supergiants
# KA Pollard, Mumbai Indians
# Harbhajan Singh, Mumbai Indians
# M Ashwin, Rising Pune Supergiants
# R Bhatia, Rising Pune Supergiants
# R Ashwin, Rising Pune Supergiants
# R Vinay Kumar, Mumbai Indians
# MJ McClenaghan, Mumbai Indians
# AM Rahane, Rising Pune Supergiants
# F du Plessis, Rising Pune Supergiants
# JJ Bumrah, Mumbai Indians
# S Gopal, Mumbai Indians
# KP Pietersen, Rising Pune Supergiants
# RV Uthappa, Kolkata Knight Riders
# G Gambhir, Kolkata Knight Riders
# Z Khan, Delhi Daredevils
# NM Coulter-Nile, Delhi Daredevils
# CH Morris, Delhi Daredevils
# CR Brathwaite, Delhi Daredevils
# A Mishra, Delhi Daredevils
# MK Pandey, Kolkata Knight Riders
# JW Hastings, Kolkata Knight Riders
# MA Agarwal, Delhi Daredevils
# ...

# %%
num_mat = 0
c_ = 0
for index,data in data_2016.iterrows():
    if(match_exists.get(data['id']) == None):
        #, data['result'], data['result_margin'], data['umpire1'],data['umpire2'], 0,0,0,0)
        new_match = Match(data['id'], team_exists[data['toss_winner']], data['toss_decision'], data['date'], data['city'], data['venue'], team_exists[data['team1']], team_exists[data['team2']],team_exists[data['winner']], data['result'], data['result_margin'], data['umpire1'],data['umpire2'], 0,0,0,0,data['player_of_match'])
        match_exists[data['id']] = 1
        num_mat += 1
        print(data['winner'])
        print(num_mat)
        matches[data['id']] = new_match
        
    
    if(data['batting_team'] == teams[matches[data['id']].team1].team_name):
        matches[data['id']].team1_runs += int(data['total_runs'])
        
    if(data['batting_team'] == teams[matches[data['id']].team2].team_name):
        matches[data['id']].team2_runs += int(data['total_runs'])
        
    if(data['bowling_team'] == teams[matches[data['id']].team1].team_name):
        matches[data['id']].team2_wickets += int(data['is_wicket'])
        
    if(data['bowling_team'] == teams[matches[data['id']].team2].team_name):
        matches[data['id']].team1_wickets += int(data['is_wicket'])
    
    players[player_exists[data['batsman']]].runs += int(data['batsman_runs'])
    #print(players[player_exists[[data['bowler']]]].num_of_balls_bowled)
    players[player_exists[data['bowler']]].num_of_balls_bowled += 1
    players[player_exists[data['bowler']]].num_runs_given += data['total_runs']
    #print(type(data['extras_type']))     
    c_ += 1
    if((data['extras_type'] == 'nan') or type(data['extras_type']) == type(0.1) or data['extras_type'] == 'legbyes'or data['extras_type'] == 'no_ball'):
        players[player_exists[data['batsman']]].number_of_balls_faced += 1
            
            
    if(data['batsman_runs'] == 4 or data['batsman_runs'] == 6):
        players[player_exists[data['batsman']]].number_of_boundries += 1
    
    if(data['batsman_runs'] == 4):
        players[player_exists[data['batsman']]].number_of_fours += 1
    
    if(data['batsman_runs'] == 6):
        players[player_exists[data['batsman']]].number_of_sixes += 1
    
    if(type(data['player_dismissed']) == type(0.0)):
        players[player_exists[data['batsman']]].dismissals += 1
   
    #print(data['dismissal_kind'])
    if(data['dismissal_kind'] != 'run out' and int(data['is_wicket']) > 0):
        players[player_exists[data['bowler']]].wickets += 1
    
    #print(data['dismissal_kind'])
    try :
        if(data['dismissal_kind'] == 'caught'):
            #print("hello")
            players[player_exists[data['fielder']]].num_catches += 1
    except KeyError:
        pass
    
    if(data['dismissal_kind'] == 'run out'):
        players[player_exists[data['batsman']]].run_outs += 1
        #print(type(data['fielder']))
        try :
            players[player_exists[data['fielder']]].run_outs_taken += 1
        except KeyError:
            if(data['fielder'].find(',') != None):
                temp = data['fielder'].split(',')
                if(player_exists.get(temp[0]) != None):
                    players[player_exists[temp[0]]].run_outs_taken += 1
            pass
# Out:
# Rising Pune Supergiants
# 1
# Kolkata Knight Riders
# 2
# Gujarat Lions
# 3
# Royal Challengers Bangalore
# 4
# Mumbai Indians
# 5
# Gujarat Lions
# 6
# Delhi Daredevils
# 7
# Kolkata Knight Riders
# 8
# Gujarat Lions
# 9
# Kings XI Punjab
# 10
# Delhi Daredevils
# 11
# Sunrisers Hyderabad
# 12
# Kolkata Knight Riders
# 13
# Mumbai Indians
# 14
# Sunrisers Hyderabad
# 15
# Royal Challengers Bangalore
# 16
# Delhi Daredevils
# 17
# Sunrisers Hyderabad
# 18
# Gujarat Lions
# 19
# Kolkata Knight Riders
# 20
# Mumbai Indians
# 21
# Rising Pune Supergiants
# 22
# Gujarat Lions
# 23
# Mumbai Indians
# 24
# Gujarat Lions
# 25
# Delhi Daredevils
# 26
# Sunrisers Hyderabad
# 27
# Kings XI Punjab
# 28
# Mumbai Indians
# 29
# Kolkata Knight Riders
# 30
# Delhi Daredevils
# 31
# Kolkata Knight Riders
# 32
# Rising Pune Supergiants
# 33
# Sunrisers Hyderabad
# 34
# Royal Challengers Bangalore
# 35
# Kings XI Punjab
# 36
# Sunrisers Hyderabad
# 37
# Gujarat Lions
# 38
# ...

# %%
for match in matches.keys():
    print(f'{teams[matches[match].winner].team_name}, {teams[matches[match].team1].team_name}, {matches[match].team1_runs}, {matches[match].team2_runs},{matches[match].team1_wickets},{matches[match].team2_wickets}')
# Out:
# Rising Pune Supergiants, Mumbai Indians, 121, 126,8,1
# Kolkata Knight Riders, Kolkata Knight Riders, 99, 98,1,10
# Gujarat Lions, Kings XI Punjab, 161, 162,6,5
# Royal Challengers Bangalore, Royal Challengers Bangalore, 227, 182,4,6
# Mumbai Indians, Kolkata Knight Riders, 187, 188,5,4
# Gujarat Lions, Gujarat Lions, 164, 163,3,5
# Delhi Daredevils, Delhi Daredevils, 113, 111,2,9
# Kolkata Knight Riders, Sunrisers Hyderabad, 142, 146,7,2
# Gujarat Lions, Mumbai Indians, 143, 147,8,7
# Kings XI Punjab, Kings XI Punjab, 153, 152,4,7
# Delhi Daredevils, Royal Challengers Bangalore, 191, 192,5,3
# Sunrisers Hyderabad, Sunrisers Hyderabad, 145, 142,3,6
# Kolkata Knight Riders, Kings XI Punjab, 138, 141,8,4
# Mumbai Indians, Mumbai Indians, 171, 170,4,7
# Sunrisers Hyderabad, Gujarat Lions, 135, 137,8,0
# Royal Challengers Bangalore, Rising Pune Supergiants, 172, 185,9,3
# Delhi Daredevils, Delhi Daredevils, 164, 154,4,7
# Sunrisers Hyderabad, Sunrisers Hyderabad, 146, 143,5,6
# ...

# %%
num_pl = 0
for key in players.keys():
    print(f'{players[key].player_name}, {teams[players[key].team_id].team_name}, {players[key].runs}, {players[key].wickets}')
    if(players[key].number_of_balls_faced > 0):
        players[key].strike_rate = float(float(players[key].runs) / float(players[key].number_of_balls_faced)) * 100.0
        print(players[key].strike_rate, players[key].number_of_balls_faced)
    num_pl += 1
print(num_pl)
# Out:
# RG Sharma, Mumbai Indians, 489, 0
# 133.97260273972603 365
# LMP Simmons, Mumbai Indians, 8, 0
# 100.0 8
# I Sharma, Rising Pune Supergiants, 0, 3
# RP Singh, Rising Pune Supergiants, 0, 3
# HH Pandya, Mumbai Indians, 44, 3
# 69.84126984126983 63
# AT Rayudu, Mumbai Indians, 334, 0
# 120.57761732851986 277
# JC Buttler, Mumbai Indians, 255, 0
# 139.34426229508196 183
# MR Marsh, Rising Pune Supergiants, 7, 4
# 63.63636363636363 11
# KA Pollard, Mumbai Indians, 207, 0
# 143.75 144
# Harbhajan Singh, Mumbai Indians, 92, 9
# 109.52380952380953 84
# M Ashwin, Rising Pune Supergiants, 0, 7
# 0.0 1
# R Bhatia, Rising Pune Supergiants, 34, 6
# 170.0 20
# R Ashwin, Rising Pune Supergiants, 41, 10
# 107.89473684210526 38
# R Vinay Kumar, Mumbai Indians, 13, 3
# 108.33333333333333 12
# MJ McClenaghan, Mumbai Indians, 34, 17
# 147.82608695652172 23
# AM Rahane, Rising Pune Supergiants, 480, 0
# 127.32095490716179 377
# F du Plessis, Rising Pune Supergiants, 206, 0
# 127.95031055900621 161
# ...

# %%
s = f"{}"
# Out:
#   Cell In [23], line 1
#     s = f"{}"
#              ^
# SyntaxError: f-string: empty expression not allowed

# %%
for key in teams.keys():
    print(teams[key].team_name, teams[key].points, teams[key].team_id)
    teams[key].num_Won = teams[key].points / 2
    teams[key].num_Lost = teams[key].num_of_matches - teams[key].num_Won
# Out:
# Mumbai Indians 0 1
# Kolkata Knight Riders 0 2
# Kings XI Punjab 0 3
# Royal Challengers Bangalore 0 4
# Gujarat Lions 0 5
# Delhi Daredevils 0 6
# Sunrisers Hyderabad 0 7
# Rising Pune Supergiants 0 8

# %%
for key in matches.keys():
    if(teams[matches[key].winner].num_of_matches < 14) :
        teams[matches[key].winner].points += 2
    if(teams[matches[key].team1].num_of_matches < 14) :
        teams[matches[key].team1].num_of_matches += 1
    if(teams[matches[key].team2].num_of_matches < 14) :
        teams[matches[key].team2].num_of_matches += 1

# %%
import mariadb

# %%
connection = mariadb.connect(
         host='127.0.0.1',
         port= 3306,
         user='root',
         password='we5great',
         database='sys')
cur = connection.cursor()

#cur.execute('INSERT INTO Student VALUES (28, "Eren yeager");')

# %%
insert = "INSERT INTO Team VALUES"
for key in teams.keys():
    s = f'INSERT INTO Team VALUES ({teams[key].team_id}, "{teams[key].team_name}", {teams[key].num_of_matches}, {teams[key].num_Won}, {teams[key].num_Lost}, {teams[key].points}, 0, 0);'
    cur.execute(s)
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# Cell In [29], line 4
#       2 for key in teams.keys():
#       3     s = f'INSERT INTO Team VALUES ({teams[key].team_id}, "{teams[key].team_name}", {teams[key].num_of_matches}, {teams[key].num_Won}, {teams[key].num_Lost}, {teams[key].points}, 0, 0);'
# ----> 4     cur.execute(s)
#
# File ~/.local/lib/python3.10/site-packages/mariadb/cursors.py:307, in Cursor.execute(self, statement, data, buffered)
#     304         self._transformed_statement = self.statement
#     306     self._execute_text(self._transformed_statement)
# --> 307     self._readresponse()
#     308 else:
#     309     self._data = data
#
# IntegrityError: Duplicate entry '1' for key 'PRIMARY'

# %%
cur.execute('INSERT INTO Student VALUES (28, "Eren yeager");')
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# Cell In [77], line 1
# ----> 1 cur.execute('INSERT INTO Student VALUES (28, "Eren yeager");')
#
# File ~/.local/lib/python3.10/site-packages/mariadb/cursors.py:307, in Cursor.execute(self, statement, data, buffered)
#     304         self._transformed_statement = self.statement
#     306     self._execute_text(self._transformed_statement)
# --> 307     self._readresponse()
#     308 else:
#     309     self._data = data
#
# IntegrityError: Duplicate entry '28' for key 'PRIMARY'

# %%
connection.commit()

# %%
for key in players.keys():
    it = players[key]
    s = f'INSERT INTO Player VALUES ({it.player_id}, "{it.player_name}", {it.team_id}, "{teams[it.team_id].team_name}", {it.runs},{it.wickets},{it.dismissals}, {it.innings_played}, {it.number_of_balls_faced}, {it.number_of_sixes}, {it.number_of_fours}, {it.number_of_boundries},{it.num_of_balls_bowled}, {it.run_outs}, {it.run_outs_taken}, {it.num_catches}, {it.strike_rate}, {it.num_runs_given});'              
    
    cur.execute(s)

# %%
for key in players.keys():
    it = players[key]
    s = f'INSERT INTO Player VALUES ({it.player_id}, "{it.player_name}", {it.team_id}, "{teams[it.team_id].team_name}", {it.runs},{it.wickets},{it.dismissals}, {it.innings_played}, {it.number_of_balls_faced}, {it.number_of_sixes}, {it.number_of_fours}, {it.number_of_boundries},{it.num_of_balls_bowled}, {it.run_outs}, {it.run_outs_taken}, {it.num_catches}, {it.strike_rate}, {it.num_runs_given});'              
    print(s)
# Out:
# INSERT INTO Player VALUES (1, "RG Sharma", 1, "Mumbai Indians", 489,0,360, 0, 365, 17, 49, 66,0, 3, 1, 2, 133.97260273972603, 0);
# INSERT INTO Player VALUES (2, "LMP Simmons", 1, "Mumbai Indians", 8,0,7, 0, 8, 1, 0, 1,0, 0, 0, 0, 100.0, 0);
# INSERT INTO Player VALUES (3, "I Sharma", 8, "Rising Pune Supergiants", 0,3,0, 0, 0, 0, 0, 0,97, 0, 0, 2, 0.0, 151);
# INSERT INTO Player VALUES (4, "RP Singh", 8, "Rising Pune Supergiants", 0,3,0, 0, 0, 0, 0, 0,76, 0, 0, 0, 0.0, 114);
# INSERT INTO Player VALUES (5, "HH Pandya", 1, "Mumbai Indians", 44,3,59, 0, 63, 0, 4, 4,106, 0, 0, 6, 69.84126984126983, 155);
# INSERT INTO Player VALUES (6, "AT Rayudu", 1, "Mumbai Indians", 334,0,273, 0, 277, 12, 28, 40,0, 0, 1, 4, 120.57761732851986, 0);
# INSERT INTO Player VALUES (7, "JC Buttler", 1, "Mumbai Indians", 255,0,178, 0, 183, 11, 23, 34,0, 0, 0, 7, 139.34426229508196, 0);
# ...

# %%
players[16].player_name
# Out:
# 'AM Rahane'

# %%
CREATE table Player (
    player_id INT PRIMARY KEY,
    player_name VARCHAR(255),
    team_id INT,
    t_name VARCHAR(255),
    runs INT,
    wickets INT,
    dismissals INT, 
    innings_played INT,
    balls_faced INT,
    sixes INT,
    fours INT,
    boundries INT,
    balls_bowled INT,
    run_outs INT,
    run_outs_taken INT,
    catches INT,
    strike_rate FLOAT,
    runs_given INT
);

# %%
type(data_2016)
# Out:
# pandas.core.frame.DataFrame

# %%
print(data_2016.keys())
# Out:
# Index(['id', 'inning', 'over', 'ball', 'batsman', 'non_striker', 'bowler',
#        'batsman_runs', 'extra_runs', 'total_runs', 'non_boundary', 'is_wicket',
#        'dismissal_kind', 'player_dismissed', 'fielder', 'extras_type',
#        'batting_team', 'bowling_team', 'city', 'date', 'player_of_match',
#        'venue', 'neutral_venue', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'winner', 'result', 'result_margin', 'eliminator',
#        'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
data_2016
# Out:
#             id  inning  over  ball         batsman     non_striker  \
# 122434  980901       1     1     1       RG Sharma     LMP Simmons
# 122435  980901       1     0     4       RG Sharma     LMP Simmons
# 122436  980901       1     0     5       RG Sharma     LMP Simmons
# 122437  980901       1     0     6     LMP Simmons       RG Sharma
# 122438  980901       1     1     5       HH Pandya     LMP Simmons
# ...        ...     ...   ...   ...             ...             ...
# 136525  981019       2     6     4         V Kohli        CH Gayle
# 136526  981019       2    12     2         V Kohli  AB de Villiers
# 136527  981019       2    12     3         V Kohli  AB de Villiers
# 136528  981019       2    11     6  AB de Villiers         V Kohli
# 136529  981019       2    12     1  AB de Villiers         V Kohli
#
#               bowler  batsman_runs  extra_runs  total_runs  non_boundary  \
# 122434      I Sharma             0           0           0             0
# ...

# %%
Create table Delivery(
delivery_id INT PRIMARY KEY,
match_id INT,
inning INT,
over INT, 
ball INT, 
batsman VARCHAR(255), 
non_striker VARCHAR(255), 
bowler VARCHAR(255),
batsman_runs INT, 
extra_runs INT, 
total_runs INT, 
non_boundary INT, 
is_wicket INT,
dismissal_kind VARCHAR(255), 
player_dismissed VARCHAR(255), 
fielder VARCHAR(255), 
extras_type VARCHAR(255),
batting_team VARCHAR(255), 
bowling_team VARCHAR(255), 
city VARCHAR(255), 
date VARCHAR(255), 
player_of_match VARCHAR(255),
venue VARCHAR(255), 
neutral_venue INT, 
team1 VARCHAR(255), 
team2 VARCHAR(255), 
toss_winner VARCHAR(255),
toss_decision VARCHAR(255), 
winner VARCHAR(255), 
result VARCHAR(255), 
result_margin INT, 
eliminator VARCHAR(255),
method VARCHAR(255), 
umpire1 VARCHAR(255), 
umpire2 VARCHAR(255)
);

# %%
for index, data in data_2016.iterrows():
    cur.execute(f'INSERT INTO Delivery VALUES ({index}, {data["id"]}, {data["inning"]}, {data["over"]}, {data["ball"]}, "{data["batsman"]}", "{data["non_striker"]}", "{data["bowler"]}", {data["batsman_runs"]}, {data["extra_runs"]}, {data["total_runs"]}, {data["non_boundary"]}, {data["is_wicket"]}, "{data["dismissal_kind"]}", "{data["player_dismissed"]}", "{data["fielder"]}", "{data["extras_type"]}", "{data["batting_team"]}", "{data["bowling_team"]}", "{data["city"]}", "{data["date"]}", "{data["player_of_match"]}", "{data["venue"]}", {data["neutral_venue"]}, "{data["team1"]}", "{data["team2"]}", "{data["toss_winner"]}", "{data["toss_decision"]}", "{data["winner"]}", "{data["result"]}", {data["result_margin"]}, "{data["eliminator"]}", "{data["method"]}", "{data["umpire1"]}", "{data["umpire2"]}");')
    #print(f'INSERT INTO Delivery VALUES ({data["id"]}, {data["inning"]}, {data["over"]}, {data["ball"]}, "{data["batsman"]}", "{data["non_striker"]}", "{data["bowler"]}", {data["batsman_runs"]}, {data["extra_runs"]}, {data["total_runs"]}, {data["non_boundary"]}, {data["is_wicket"]}, "{data["dismissal_kind"]}", "{data["player_dismissed"]}", "{data["fielder"]}", "{data["extras_type"]}", "{data["batting_team"]}", "{data["bowling_team"]}", "{data["city"]}", "{data["date"]}", "{data["player_of_match"]}", "{data["venue"]}", {data["neutral_venue"]}, "{data["team1"]}", "{data["team2"]}", "{data["toss_winner"]}", "{data["toss_decision"]}", "{data["winner"]}", "{data["result"]}", {data["result_margin"]}, "{data["eliminator"]}", "{data["method"]}", "{data["umpire1"]}", "{data["umpire2"]}");')

# %%
k = ['id', 'inning', 'over', 'ball', 'batsman', 'non_striker', 'bowler', 'batsman_runs', 'extra_runs', 'total_runs', 'non    _boundary', 'is_wicket', 'dismissal_kind', 'player_dismissed', 'fielder', 'extras_type', 'batting_team', 'bowling_team',     'city', 'date', 'player_of_match', 'venue', 'neutral_venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner','result', 'result_margin', 'eliminator', 'method', 'umpire1','umpire2']

# %%
len(k)
# Out:
# 34

# %%
s = "INSERT INTO Delivery VALUES ("
for ele in k:
    a = "{"
    a += f'data["{ele}"]'
    a += "}, "
    s += a
s = s[0:-2]
s += ");"
print(s)
# Out:
# INSERT INTO Delivery VALUES ({data["id"]}, {data["inning"]}, {data["over"]}, {data["ball"]}, {data["batsman"]}, {data["non_striker"]}, {data["bowler"]}, {data["batsman_runs"]}, {data["extra_runs"]}, {data["total_runs"]}, {data["non    _boundary"]}, {data["is_wicket"]}, {data["dismissal_kind"]}, {data["player_dismissed"]}, {data["fielder"]}, {data["extras_type"]}, {data["batting_team"]}, {data["bowling_team"]}, {data["city"]}, {data["date"]}, {data["player_of_match"]}, {data["venue"]}, {data["neutral_venue"]}, {data["team1"]}, {data["team2"]}, {data["toss_winner"]}, {data["toss_decision"]}, {data["winner"]}, {data["result"]}, {data["result_margin"]}, {data["eliminator"]}, {data["method"]}, {data["umpire1"]}, {data["umpire2"]});

# %%
f'INSERT INTO Delivery VALUES ({data["id"]}, {data["inning"]}, {data["over"]}, {data["ball"]}, "{data["batsman"]}", "{data["non_striker"]}", "{data["bowler"]}", {data["batsman_runs"]}, {data["extra_runs"]}, {data["total_runs"]}, {data["non_boundary"]}, {data["is_wicket"]}, "{data["dismissal_kind"]}", "{data["player_dismissed"]}", "{data["fielder"]}", "{data["extras_type"]}", "{data["batting_team"]}", "{data["bowling_team"]}", "{data["city"]}", "{data["date"]}", "{data["player_of_match"]}", "{data["venue"]}", {data["neutral_venue"]}, "{data["team1"]}", "{data["team2"]}", "{data["toss_winner"]}", "{data["toss_decision"]}", "{data["winner"]}", "{data["result"]}", {data["result_margin"]}, "{data["eliminator"]}", "{data["method"]}", "{data["umpire1"]}", "{data["umpire2"]}");'
# Out:
# 'INSERT INTO Delivery VALUES (980901, 1, 1, 1, "RG Sharma", "LMP Simmons", "I Sharma", 0, 0, 0, 0, 1, "lbw", "RG Sharma", "nan", "nan", "Mumbai Indians", "Rising Pune Supergiants", "Mumbai", "2016-04-09", "AM Rahane", "Wankhede Stadium", 0, "Mumbai Indians", "Rising Pune Supergiants", "Mumbai Indians", "bat", "Rising Pune Supergiants", "wickets", 9.0, "N", "nan", "HDPK Dharmasena", "CK Nandan");'

# %%
cur.execute('SELECT * FROM Match_')

# %%
t = cur.fetchall()
for i in range(8):
    print(t[i])
# Out:
# (980901, datetime.date(2016, 4, 9), 1, 'Mumbai Indians', 8, 'Rising Pune Supergiants', 'Wankhede Stadium', 'Mumbai', 1, 'Mumbai Indians', 'bat', 8, 'Rising Pune Supergiants', 'wickets', 9, 'HDPK Dharmasena', 'CK Nandan', 121, 126, 8, 1, 16, 'AM Rahane')
# (980903, datetime.date(2016, 4, 10), 2, 'Kolkata Knight Riders', 6, 'Delhi Daredevils', 'Eden Gardens', 'Kolkata', 2, 'Kolkata Knight Riders', 'field', 2, 'Kolkata Knight Riders', 'wickets', 9, 'S Ravi', 'C Shamshuddin', 99, 98, 1, 10, 32, 'AD Russell')
# (980905, datetime.date(2016, 4, 11), 3, 'Kings XI Punjab', 5, 'Gujarat Lions', 'Punjab Cricket Association IS Bindra Stadium, Mohali', 'Chandigarh', 5, 'Gujarat Lions', 'field', 5, 'Gujarat Lions', 'wickets', 5, 'AK Chaudhary', 'VA Kulkarni', 161, 162, 6, 5, 53, 'AJ Finch')
# ...
